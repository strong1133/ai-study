# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b")

llm.invoke("who am i")
# Out:
# AIMessage(content="I don't have any information about your identity or who you are. This is the beginning of our conversation, and I'm a large language model, I don't retain any information about individual users. If you'd like to talk about yourself or share what's on your mind, I'm here to listen!", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-12-22T06:35:31.090887Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9906776916, 'load_duration': 8596422708, 'prompt_eval_count': 28, 'prompt_eval_duration': 282105458, 'eval_count': 63, 'eval_duration': 723016963, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019b44c5-04dd-7bd0-a7bc-bdc8346b0568-0', usage_metadata={'input_tokens': 28, 'output_tokens': 63, 'total_tokens': 91})

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser


prompt_template = PromptTemplate(
    template="What is the capital of the {country}? Return the name of city only",
    input_variables=["country"],
)

prompt = prompt_template.invoke({"country": "korea"})
ai_message =  llm.invoke(prompt)

output_parser = StrOutputParser()
answer = output_parser.invoke(llm.invoke(prompt))

# %%
print(ai_message)
# Out:
# content='Seoul' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-12-22T06:35:33.596083Z', 'done': True, 'done_reason': 'stop', 'total_duration': 201817750, 'load_duration': 95833708, 'prompt_eval_count': 40, 'prompt_eval_duration': 65356375, 'eval_count': 3, 'eval_duration': 23081875, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'} id='lc_run--019b44c5-3491-7a40-bc6c-bc44094e655c-0' usage_metadata={'input_tokens': 40, 'output_tokens': 3, 'total_tokens': 43}

# %%
print(answer)
# Out:
# Seoul.

# %%
from locale import currency
from pydantic import BaseModel, Field

class CountryDetail(BaseModel):
    capital: str = Field(description="The capital of the country")
    population: int = Field(description="The  population the country")
    language: str = Field(description="The language of the country")
    currency: str = Field(description="The currency of the country")

structured_llm = llm.with_structured_output(CountryDetail)

# %%
from langchain_core.output_parsers import JsonOutputParser

country_detail_propmt = PromptTemplate(
    template="""Give following information about {country}:
    - Capit
    - Population
    - Language
    - Currency
    
    return it in JSON format. and return the JSON dictionary only
    """,
    input_variables=["country"]
)

json_ai_message = structured_llm.invoke(country_detail_propmt.invoke({"country": "korea"}))

# %%
(json_ai_message)
# Out:
# CountryDetail(capital='Seoul', population=51, language='Korean', currency='South Korean won')

# %%
json_ai_message.model_dump()
# Out:
# {'capital': 'Seoul',
#  'population': 51,
#  'language': 'Korean',
#  'currency': 'South Korean won'}
