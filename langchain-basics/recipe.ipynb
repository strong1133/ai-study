# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b")

# %%
# 음식 이름 찾기

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate


food_prompt = PromptTemplate(
    template='''What is one of the most popular food in {country}?
    Please return the name of the food only''',
    input_variables=["country"]
)


food_chain = food_prompt| llm | StrOutputParser()

# %%
food_chain.invoke({'country':'italy'})
# Out:
# 'Pizza.'

# %%
from langchain_core.prompts import ChatPromptTemplate


recipe_prompt = ChatPromptTemplate.from_messages([
    ('system','''Provide the recipe of the food that the user wants. Please return the recipe only as a numbered list'''),
    ('human','Can you give me the recipe for making {food}')
])

recipe_chain = recipe_prompt | llm | StrOutputParser()

# %%
recipe_chain.invoke({'food':'bibimbab'})
# Out:
# "Here's the traditional Korean dish Bibimbap:\n\n1. Prepare the ingredients:\n   - 80g beef (sirloin or ribeye), sliced into thin strips\n   - 2 cups mixed vegetables ( bean sprouts, zucchini, carrots, green onions)\n   - 2 eggs\n   - 1 cup kimchi, chopped\n   - 1/4 cup Gochujang (Korean chili paste)\n   - 2 tablespoons soy sauce\n   - 1 tablespoon sesame oil\n   - Salt and pepper to taste\n   - Bibimbap bowl\n   - Rice\n\n2. Cook the beef:\n   - Heat 1 tablespoon of sesame oil in a pan over medium-high heat.\n   - Add the beef and cook until browned, about 3-4 minutes.\n   - Remove from heat and set aside.\n\n3. Cook the vegetables:\n   - Heat another tablespoon of sesame oil in the same pan.\n   - Add the mixed vegetables and cook until tender-crisp, about 2-3 minutes.\n   - Season with salt and pepper to taste.\n\n4. Make the fried egg:\n   - Crack an egg into a separate pan and fry over medium heat until cooked to your desired doneness.\n\n5. Assemble Bibimbap:\n   - Divide the cooked rice onto four bowls.\n   - Arrange the beef, vegetables, and fried egg on top of the rice in each bowl.\n   - Sprinkle kimchi over the ingredients.\n   - Drizzle Gochujang and soy sauce over the dish.\n\n6. Serve and enjoy:\n   - Serve immediately and let everyone build their own Bibimbap bowls according to their preference.\n\nNote: This recipe makes 4 servings."

# %%
final_chain = {'food':food_chain} | recipe_chain

# %%
final_chain.invoke({'country':'japan'})
# Out:
# 'Here is a classic recipe for making sushi at home:\n\n**Ingredients:**\n\nFor the Nori sheets:\n\n* 1 package of nori seaweed sheets (about 20-24 sheets)\n\nFor the Fillings:\n\n* 1 cup cooked and cooled Japanese rice\n* 1/2 cup sliced cucumber\n* 1/2 cup sliced carrots\n* 1/4 cup sliced avocado\n* 1/4 cup cream cheese, softened\n* 1/2 teaspoon salt\n\nFor the Sushi Rolls:\n\n* 1-2 sheets of nori seaweed\n* Fillings of your choice (e.g. raw fish, cooked shrimp, etc.)\n* Rice vinegar solution (see below)\n* Sugar and salt for seasoning\n\n**Rice Vinegar Solution:**\n\n* 1 cup rice vinegar\n* 1 tablespoon sugar\n* 1 teaspoon salt\n\n**Instructions:**\n\n1. Prepare the nori sheets by soaking them in water for a few minutes to make them pliable.\n2. Cook the Japanese rice according to package instructions and let it cool down.\n3. Prepare the fillings by slicing the cucumber, carrots, avocado, and cream cheese into thin pieces.\n4. Mix the cooled sushi rice with the rice vinegar solution and season with sugar and salt.\n5. Lay a nori sheet flat on a surface and spread a thin layer of sushi rice onto it, leaving about 1 inch of space at the top.\n6. Arrange your chosen fillings horizontally in the middle of the rice.\n7. Using a bamboo sushi mat or a piece of parchment paper, roll the nori sheet tightly around the filling to form a compact cylinder.\n8. Repeat steps 5-7 with the remaining ingredients and nori sheets.\n9. Slice the rolls into individual pieces using a sharp knife.\n10. Serve your homemade sushi immediately.\n\n**Tips:**\n\n* Use short-grain Japanese rice, as it is specifically designed for making sushi.\n* Handle the nori sheets gently to prevent them from tearing.\n* Make sure the fillings are evenly distributed and not too thick or too thin.\n* Experiment with different fillings and seasonings to create unique sushi combinations.'
