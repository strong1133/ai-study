# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="deepseek-r1:1.5b")

llm.invoke("Hello, Where is the capital of the korea? language for response is korean")
# Out:
# AIMessage(content='The capital of South Korea is Seoul. However, there are several significant cities in different regions that may serve as capitals for various reasons such as regional importance or strategic location. These include Pusan (Cheonggye Province) and Gyeongju, which might have capitals like Pusan and Gyeongju respectively.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-12-22T04:33:01.654987Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7421308333, 'load_duration': 88419041, 'prompt_eval_count': 20, 'prompt_eval_duration': 94750750, 'eval_count': 461, 'eval_duration': 4635449447, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--019b4454-e9d8-79e0-bfee-b17766997904-0', usage_metadata={'input_tokens': 20, 'output_tokens': 461, 'total_tokens': 481})

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

llm.invoke("Hello, Where is the capital of the korea? language for response is korean")
# Out:
# AIMessage(content='안녕하세요. 한국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 22, 'total_tokens': 32, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CpRyaR9MtKnyO2BZQwNSY32Ddigz8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b4459-f03d-7562-bedf-525642885d84-0', usage_metadata={'input_tokens': 22, 'output_tokens': 10, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
