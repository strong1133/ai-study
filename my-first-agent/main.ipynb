# %%
import openai

client = openai.OpenAI()

# response  = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role": "user", "content": "What is the capital of South Korea?"},
#     ],
# )

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "한국의 수도는 어디야?"},
    ],
)

response = response.choices[0].message.content
print(response)
# Out:
# 한국의 수도는 서울입니다.

# %%
import openai

client = openai.OpenAI()

PROMPT = """
내 시스템에 아래와 같은 함수들이 있어
`get_weather`
`get_currency`
`get_news`

이 함수들은 모두 나라의 이름을 인자로 받아. 예를들어 (get_weather('한국'))
이제 내가 실행해야 할 함수를 알려줘.
다른 사항은 언급하지 않고 함수 이름만 알려줘.

내가 물어볼 질문은
스페인의 날씨는 어떤가요? 
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": PROMPT},
    ],
)

response = response.choices[0].message.content
print(response)
# Out:
# `get_weather('스페인')`

# %%
# 메모리 셋팅
from email import message
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(model="gpt-4o-mini", messages=messages)
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM")
    if message == "exit":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: 안녕 내 이름은 정석진이야
# AI: 안녕하세요, 정석진님! 어떻게 도와드릴까요?
# User: 내이름이 뭐였지?
# AI: 정석진님이시죠! 다시 한 번 말씀해 주셔서 감사합니다. 다른 궁금한 점이나 필요한 것이 있으면 말씀해 주세요!
# User: 내 국적은?
# AI: 당신의 국적에 대한 정보는 제가 알지 못하지만, 질문을 통해 유추할 수는 없습니다. 추가적인 정보를 제공해 주시면 도와드릴 수 있는 부분이 있을지도 모르니 말씀해 주세요!
# User: 내 국적은 한국이야
# AI: 감사합니다, 정석진님! 한국이시군요. 한국에 대해 궁금한 점이나 다른 주제에 대해 이야기하고 싶은 것이 있으면 언제든지 말씀해 주세요!
# User: 내 국적이 뭐라고?
# AI: 정석진님은 한국 국적이시라고 말씀하셨어요. 다른 질문이 있으시면 언제든지 해주세요!
# User: 내 인적사항을 말해봐
# AI: 죄송하지만, 개인 정보나 인적 사항에 대한 접근 권한이 없습니다. 당신이 공유한 정보만 기억할 수 있으며, 그 외의 정보는 알 수 없습니다. 다른 질문이나 도움을 원하는 부분이 있다면 말씀해 주세요!
# User: 내가 처음 물어본게 뭐였지?
# AI: 처음에 "내 이름이 뭐였지?"라고 물어보셨습니다. 그때 당신의 이름은 정석진이라고 말씀해 주셨죠. 추가로 궁금한 점이 있으시면 언제든지 말씀해 주세요!
# User: 그다음은?
# AI: 그다음에는 "내 국적은?"이라고 물어보셨고, 제가 기억하고 있던 바에 따르면, 당신의 국적은 한국이라고 답하셨습니다. 다른 질문이나 도움이 필요하시면 말씀해 주세요!
