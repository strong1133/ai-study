# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI


llm = ChatOpenAI()

# %%
ai_message =  llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
(ai_message.content)
# Out:
# '인프런에는 다양한 분야의 강의들이 있습니다. 프로그래밍, 디자인, 비즈니스, 언어학습, 취미 등 다양한 주제의 강의들이 있어서 자신에게 필요한 분야에 맞는 강의를 선택하여 학습할 수 있습니다. 또한 인기 있는 유튜버나 전문가들이 진행하는 프리미엄 강의도 많이 제공되고 있습니다. 해당 사이트를 방문하여 자신에게 필요한 강의를 찾아보시면 됩니다.'
